# %% [markdown]
# <a href="https://colab.research.google.com/github/kushv16/Audio-Sentiment-Analysis/blob/master/ResNet_Pre_trained_%7C_2D_MFCC_features_%7C_Without_CremaD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# import libraries
import pandas as pd
import numpy as np
import librosa
import librosa.display
import random
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# !pip install tqdm

from tqdm import tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)

# %%
df = pd.read_csv('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/combo_with_cleaned_paths.csv', index_col=0)


df.sample()
# Out:
#                                                     path  \
# 12339  /content/drive/MyDrive/LY Project/Cleaned Data...
#
#                                 filename    dataset  duration  sample_rate  \
# 12339  female2_neutral_12a_2_cleaned.wav  JL-Corpus      1.65        44100
#
#        gender  age  emotion     f0_mean   f0_median  ...  mfcc22_var  \
# 12339  female   30  neutral  158.921087  157.825829  ...    34.77934
#
#        mfcc23_var  mfcc24_var  mfcc25_var  mfcc26_var  mfcc27_var  mfcc28_var  \
# 12339   16.365849   23.306627   21.820951   22.950708   14.079849   15.754153
#
#        mfcc29_var  mfcc30_var  \
# 12339   20.246517   15.402141
#
#                                                    mfccs
# 12339  [[-739.3859    -647.59534   -588.41925   ... -...
#
# [1 rows x 98 columns]

# %%
df = df[df['dataset'] != 'CREMA-D']
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (9343, 98)

# %%
# Select target
df['emotion'].replace({'angry':0,'disgust':1,'fear':2,'happy':3,'neutral':4,'sad':5,'surprise':6}, inplace=True)
y = df.emotion.values

# %%
x_tr = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_tr.npy')
x_va = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_va.npy')
x_te = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_te.npy')

y_tr = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_tr.npy')
y_va = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_va.npy')
y_te = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_te.npy')

# %%
x_tr.shape, x_va.shape, x_te.shape, y_tr.shape, y_va.shape, y_te.shape
# Out:
# ((5885, 30, 200), (2523, 30, 200), (935, 30, 200), (5885,), (2523,), (935,))

# %%
# Get mean and standard deviation from the training set
tr_mean = np.mean(x_tr, axis=0)
tr_std = np.std(x_tr, axis=0)

# Apply data scaling
x_tr = (x_tr - tr_mean)/tr_std
x_va = (x_va - tr_mean)/tr_std
x_te = (x_te - tr_mean)/tr_std

# %%
# Add the 'channel' dimension to the MFCCs spectrum input 'images'
print(f"x_tr has a dimension of {x_tr.shape} before the manipulation.")

x_tr = x_tr[..., None]
x_va = x_va[..., None]
x_te = x_te[..., None]

print(f"x_tr has a dimension of {x_tr.shape} after the manipulation.")
# Out:
# x_tr has a dimension of (5885, 30, 200) before the manipulation.
# x_tr has a dimension of (5885, 30, 200, 1) after the manipulation.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
import tensorflow_hub as hub

def resnet_block(inputs, num_filters, kernel_size, strides, activation='relu'):
    x = keras.layers.Conv2D(num_filters, kernel_size=kernel_size, strides=strides, padding='same')(inputs)
    x = keras.layers.BatchNormalization()(x)
    if activation:
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv2D(num_filters, kernel_size=kernel_size, strides=1, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    if activation:
        x = keras.layers.Activation(activation)(x)
    if strides > 1:
        shortcut = keras.layers.Conv2D(num_filters, kernel_size=1, strides=strides, padding='same')(inputs)
        shortcut = keras.layers.BatchNormalization()(shortcut)
    else:
        shortcut = inputs
    x = keras.layers.add([x, shortcut])
    x = keras.layers.Activation(activation)(x)
    return x

def resnet(input_shape, num_classes, num_filters=64, num_blocks=[2, 2, 2, 2], kernel_size=3, strides=1, activation='relu'):
    inputs = keras.layers.Input(shape=input_shape)
    x = keras.layers.Conv2D(num_filters, kernel_size=7, strides=2, padding='same')(inputs)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation(activation)(x)
    x = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)
    
    for i, num_blocks in enumerate(num_blocks):
        for j in range(num_blocks):
            strides = 1
            if j == 0 and i > 0:
                strides = 2
            x = resnet_block(x, num_filters, kernel_size, strides, activation=activation)
        num_filters *= 2
    
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes, activation='softmax')(x)
    model = keras.models.Model(inputs=inputs, outputs=x)
    return model

model = resnet(input_shape=(30, 200, 1), num_classes=7)
# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 30, 200, 1)  0           []
#                                 ]
#
#  conv2d_16 (Conv2D)             (None, 15, 100, 64)  3200        ['input_2[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 15, 100, 64)  256        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 15, 100, 64)  0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 8, 50, 64)   0           ['activation_12[0][0]']
#  )
#
#  conv2d_17 (Conv2D)             (None, 8, 50, 64)    36928       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 50, 64)   256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 50, 64)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 50, 64)    36928       ['activation_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 50, 64)   256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 8, 50, 64)    0           ['batch_normalization_19[0][0]']
#
#  add (Add)                      (None, 8, 50, 64)    0           ['activation_14[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  activation_15 (Activation)     (None, 8, 50, 64)    0           ['add[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 50, 64)    36928       ['activation_15[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 50, 64)   256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 8, 50, 64)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 50, 64)    36928       ['activation_16[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 50, 64)   256         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 50, 64)    0           ['batch_normalization_21[0][0]']
#
#  add_1 (Add)                    (None, 8, 50, 64)    0           ['activation_17[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 8, 50, 64)    0           ['add_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 25, 128)   73856       ['activation_18[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 4, 25, 128)  512         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 4, 25, 128)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 4, 25, 128)   147584      ['activation_19[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 4, 25, 128)  512         ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 4, 25, 128)   8320        ['activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 4, 25, 128)   0           ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 4, 25, 128)  512         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 4, 25, 128)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_21 (Activation)     (None, 4, 25, 128)   0           ['add_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 4, 25, 128)   147584      ['activation_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 4, 25, 128)  512         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 4, 25, 128)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 25, 128)   147584      ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 4, 25, 128)  512         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 4, 25, 128)   0           ['batch_normalization_26[0][0]']
#
#  add_3 (Add)                    (None, 4, 25, 128)   0           ['activation_23[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (None, 4, 25, 128)   0           ['add_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 2, 13, 256)   295168      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 13, 256)  1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2, 13, 256)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 13, 256)   590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 13, 256)  1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 2, 13, 256)   33024       ['activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 2, 13, 256)   0           ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 2, 13, 256)  1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 2, 13, 256)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_27 (Activation)     (None, 2, 13, 256)   0           ['add_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 2, 13, 256)   590080      ['activation_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 2, 13, 256)  1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 2, 13, 256)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 2, 13, 256)   590080      ['activation_28[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 13, 256)  1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 2, 13, 256)   0           ['batch_normalization_31[0][0]']
#
#  add_5 (Add)                    (None, 2, 13, 256)   0           ['activation_29[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 2, 13, 256)   0           ['add_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 1, 7, 512)    1180160     ['activation_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 1, 7, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 1, 7, 512)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 1, 7, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 1, 7, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 1, 7, 512)    131584      ['activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 1, 7, 512)    0           ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 1, 7, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 1, 7, 512)    0           ['activation_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_33 (Activation)     (None, 1, 7, 512)    0           ['add_6[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 1, 7, 512)    2359808     ['activation_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 7, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 1, 7, 512)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 1, 7, 512)    2359808     ['activation_34[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 1, 7, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 1, 7, 512)    0           ['batch_normalization_36[0][0]']
#
#  add_7 (Add)                    (None, 1, 7, 512)    0           ['activation_35[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 1, 7, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_36[0][0]']
#  alAveragePooling2D)
#
#  dense_6 (Dense)                (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 11,188,231
# Trainable params: 11,178,631
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
from tensorflow import keras

# Compile the model using Adam's default learning rate
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(class_weight = "balanced", classes= np.unique(y_tr), y= y_tr)
class_weights = dict(zip(np.unique(y_tr), class_weights))

# Create 'EarlyStopping' callback
earlystopping_cb = keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True)

# %%
# %%time

#  Trains the neural network
history = model.fit(
    x=x_tr,
    y=y_tr,
    epochs=1000,
    batch_size=32,
    validation_data=(x_va, y_va),
    callbacks=[earlystopping_cb],
    class_weight=class_weights,
)
# Out:
# Epoch 1/1000
# 184/184 [==============================] - 22s 43ms/step - loss: 1.0302 - accuracy: 0.6494 - val_loss: 1.8142 - val_accuracy: 0.3127
# Epoch 2/1000
# 184/184 [==============================] - 6s 33ms/step - loss: 0.6481 - accuracy: 0.7798 - val_loss: 2.4774 - val_accuracy: 0.4154
# Epoch 3/1000
# 184/184 [==============================] - 6s 33ms/step - loss: 0.4947 - accuracy: 0.8275 - val_loss: 1.2564 - val_accuracy: 0.6500
# Epoch 4/1000
# 184/184 [==============================] - 6s 35ms/step - loss: 0.4124 - accuracy: 0.8518 - val_loss: 0.6043 - val_accuracy: 0.8034
# Epoch 5/1000
# 184/184 [==============================] - 6s 33ms/step - loss: 0.3405 - accuracy: 0.8785 - val_loss: 0.4702 - val_accuracy: 0.8403
# Epoch 6/1000
# 184/184 [==============================] - 7s 38ms/step - loss: 0.2712 - accuracy: 0.9033 - val_loss: 0.4719 - val_accuracy: 0.8359
# Epoch 7/1000
# Epoch 28/1000
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0534 - accuracy: 0.9822 - val_loss: 1.0066 - val_accuracy: 0.8197
# Epoch 29/1000
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0337 - accuracy: 0.9898 - val_loss: 1.0628 - val_accuracy: 0.7939
# Epoch 30/1000
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0200 - accuracy: 0.9917 - val_loss: 0.7034 - val_accuracy: 0.8573
# Epoch 31/1000
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.6490 - val_accuracy: 0.8736
# Epoch 32/1000
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.5117 - val_accuracy: 0.8946
# Epoch 33/1000
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.7462 - val_accuracy: 0.8557
# Epoch 34/1000
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0269 - accuracy: 0.9910 - val_loss: 0.5277 - val_accuracy: 0.8823
# Epoch 35/1000
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0175 - accuracy: 0.9924 - val_loss: 0.6219 - val_accuracy: 0.8625
# CPU times: user 3min 29s, sys: 5.47 s, total: 3min 35s
# Wall time: 4min 5s

# %%
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("/content/drive/MyDrive/LY Project/resnet_history.csv")

model.save_weights("/content/drive/MyDrive/LY Project/resnet_weights.h5")

# %%
# Plots neural network performance metrics for train and validation
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
plt.suptitle('ResNet with MFCCs', size=15)
results = pd.DataFrame(history.history)
results[["loss", "val_loss"]].plot(ax=axs[0])
axs[0].set_title("Validation loss {:.3f} (mean last 3)".format(np.mean(history.history["val_loss"][-3:])))
results[["accuracy", "val_accuracy"]].plot(ax=axs[1])
axs[1].set_title("Validation accuracy {:.3f} (mean last 3)".format(np.mean(history.history["val_accuracy"][-3:])))
plt.savefig("/content/drive/MyDrive/LY Project/resnet_training_curves.png")
plt.show()

# %%
# Collect loss and accuracy for the test set
loss_te, accuracy_te = model.evaluate(x_te, y_te)

print("Test loss: {:.2f}".format(loss_te))
print("Test accuracy: {:.2f}%".format(100 * accuracy_te))
# Out:
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4605 - accuracy: 0.8310
# Test loss: 0.46
# Test accuracy: 83.10%

# %%
# Compute test set predictions
predictions = model.predict(x_te)

pred = []

for i in predictions:
    pred.append(np.argmax(i))
    
from sklearn.metrics import ConfusionMatrixDisplay

labels = {'angry':0,'disgust':1,'fear':2,'happy':3,'neutral':4,'sad':5,'surprise':6}

def plot_confusion_matrices(y_true, y_pred):

    # Create two subplots
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

    # Plots the standard confusion matrix
    ax1.set_title("Confusion Matrix (counts)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, ax=ax1)

    # Plots the normalized confusion matrix
    ax2.set_title("Confusion Matrix (ratios)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, normalize="true", ax=ax2)
    plt.savefig("/content/drive/MyDrive/LY Project/resnet_confusion_matrices.png")
    plt.show()

# Plot confusion matrices
plot_confusion_matrices(y_te, pred)
# Out:
# 30/30 [==============================] - 1s 11ms/step
