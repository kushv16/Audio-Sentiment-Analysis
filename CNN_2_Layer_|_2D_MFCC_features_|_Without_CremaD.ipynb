# %% [markdown]
# <a href="https://colab.research.google.com/github/kushv16/Audio-Sentiment-Analysis/blob/master/CNN_2_Layer_%7C_2D_MFCC_features_%7C_Without_CremaD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# import libraries
import pandas as pd
import numpy as np
import librosa
import librosa.display
import random
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)

# %%
df = pd.read_csv('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/combo_with_cleaned_paths.csv', index_col=0)


df.sample()
# Out:
#                                                    path filename dataset  \
# 9128  /content/drive/MyDrive/LY Project/Cleaned Data...   KL/n19   SAVEE
#
#       duration  sample_rate gender  age  emotion     f0_mean   f0_median  ...  \
# 9128     2.812        44100   male   29  neutral  127.290635  117.216258  ...
#
#       mfcc22_var  mfcc23_var  mfcc24_var  mfcc25_var  mfcc26_var  mfcc27_var  \
# 9128    57.99474    36.70422    22.04719   37.912888    32.94282   19.474453
#
#       mfcc28_var  mfcc29_var  mfcc30_var  \
# 9128   48.306286   46.075066   60.201603
#
#                                                   mfccs
# 9128  [[-6.7299432e+02 -6.0390778e+02 -5.5903241e+02...
#
# [1 rows x 98 columns]

# %%
df = df[df['dataset'] != 'CREMA-D']
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (9343, 98)

# %%
# %%time

from tqdm import tqdm

# Create a variable where to store the mfccs data
mfccs = []

for file in tqdm(df.path):
  # load audio file:
  y, sr = librosa.load(file, sr=16000)

  # Extract 'n_mfcc' numbers of MFCCs components - in this case 30
  mfccs.append(librosa.feature.mfcc(y, sr=sr, fmin=50, n_mfcc=30))
# Out:
# 100%|██████████| 9343/9343 [2:06:54<00:00,  1.23it/s]
# CPU times: user 4min 12s, sys: 17min 58s, total: 22min 11s
# Wall time: 2h 6min 54s

# %%
# Define function to resize the 2D arrays
def resize_array(array):
    new_matrix = np.zeros((30,200))   # Initialize the new matrix shape with an array 30X200 of zeros
    for i in range(30):               # Iterate rows
        for j in range(200):          # Iterate columns
            try:       
                new_matrix[i][j] = array[i][j]
            except IndexError:                   # if mfccs of a sample is shorter than 200, then keep looping to extend lenght to 200 with 0s
                pass
    return new_matrix

# Create a variable to store the new resized mfccs and apply function for all the extracted mfccs
resized_mfccs = []

for mfcc in tqdm(mfccs):
    resized_mfccs.append(resize_array(mfcc))
# Out:
# 100%|██████████| 9343/9343 [00:52<00:00, 176.97it/s]

# %%
# Create sublots
fig, axs = plt.subplots(nrows=1,ncols=6, figsize=(20,3))

# Import normalize function to improve readibility
from matplotlib.colors import Normalize

# Select 6 random MFCCs
for i in range(6):
    index = random.randint(0, len(resized_mfccs))
    # Plot MFCCs
    librosa.display.specshow(resized_mfccs[index], sr=sr, x_axis="time", ax=axs[i], norm=Normalize(vmin=-50, vmax=50))
    axs[i].set_title(str(df['emotion'][index]) + ' - ' + str(df['duration'][index]) + ' sec')

plt.suptitle('Few MFCCs of size 30x200', size=18)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Select target
df['emotion'].replace({'angry':0,'disgust':1,'fear':2,'happy':3,'neutral':4,'sad':5,'surprise':6}, inplace=True)
y = df.emotion.values

# Features
X = resized_mfccs.copy()

# Create train, validation and test set
x_tr, x_te, y_tr, y_te = train_test_split(X, y, train_size=0.9, shuffle=True, stratify=y, random_state=0)
x_tr, x_va, y_tr, y_va = train_test_split(x_tr, y_tr, test_size=0.3, shuffle=True, stratify=y_tr, random_state=0)

# Convert data to numpy arrays
x_tr = np.array([i for i in x_tr])
x_va = np.array([i for i in x_va])
x_te = np.array([i for i in x_te])

# Plot size of dataset
print(x_tr.shape)
print(x_va.shape)
print(x_te.shape)
# Out:
# (5885, 30, 200)
# (2523, 30, 200)
# (935, 30, 200)

# %%
cd '/content/drive/MyDrive/LY Project'
# Out:
# /content/drive/.shortcut-targets-by-id/1ty6Q2chm7khBo3iSNsdx5NVqeOpCUmjM/LY Project

# %%
np.save('x_tr.npy', x_tr)
np.save('x_va.npy', x_va)
np.save('x_te.npy', x_te)

# %%
np.save('y_tr.npy', y_tr)
np.save('y_va.npy', y_va)
np.save('y_te.npy', y_te)

# %%
x_tr = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_tr.npy')
x_va = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_va.npy')
x_te = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/x_te.npy')

y_tr = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_tr.npy')
y_va = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_va.npy')
y_te = np.load('/content/drive/MyDrive/LY Project/Result and Analysis/CNN Results | 2D MFCCs | Without CremaD/y_te.npy')

# %%
x_tr.shape, x_va.shape, x_te.shape, y_tr.shape, y_va.shape, y_te.shape
# Out:
# ((5885, 30, 200, 1),
#  (2523, 30, 200, 1),
#  (935, 30, 200, 1),
#  (5885,),
#  (2523,),
#  (935,))

# %%
# Get mean and standard deviation from the training set
tr_mean = np.mean(x_tr, axis=0)
tr_std = np.std(x_tr, axis=0)

# Apply data scaling
x_tr = (x_tr - tr_mean)/tr_std
x_va = (x_va - tr_mean)/tr_std
x_te = (x_te - tr_mean)/tr_std

# %%
# Add the 'channel' dimension to the MFCCs spectrum input 'images'
print(f"x_tr has a dimension of {x_tr.shape} before the manipulation.")

x_tr = x_tr[..., None]
x_va = x_va[..., None]
x_te = x_te[..., None]

print(f"x_tr has a dimension of {x_tr.shape} after the manipulation.")
# Out:
# x_tr has a dimension of (5885, 30, 200) before the manipulation.
# x_tr has a dimension of (5885, 30, 200, 1) after the manipulation.

# %%
from tensorflow import keras
from tensorflow.keras.layers import (Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D)
from tensorflow.keras import initializers

# Create convolutional neural network and return summary
model = keras.Sequential()
model.add(Conv2D(filters=256, kernel_size=5, strides=(2, 2), activation="relu", input_shape=x_tr.shape[1:]))
model.add(MaxPool2D(pool_size=2))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=4, strides=(2, 1), activation="relu"))
model.add(MaxPool2D(pool_size=2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(units=7, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 13, 98, 256)       6656
#
#  max_pooling2d (MaxPooling2D  (None, 6, 49, 256)       0
#  )
#
#  batch_normalization (BatchN  (None, 6, 49, 256)       1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 2, 46, 128)        524416
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 23, 128)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 1, 23, 128)       512
#  hNormalization)
#
#  flatten (Flatten)           (None, 2944)              0
#
#  dropout (Dropout)           (None, 2944)              0
#
#  dense (Dense)               (None, 128)               376960
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 918,279
# Trainable params: 917,511
# Non-trainable params: 768
# _________________________________________________________________

# %%
# Compile the model using Adam's default learning rate
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(class_weight = "balanced", classes= np.unique(y_tr), y= y_tr)
class_weights = dict(zip(np.unique(y_tr), class_weights))

# Create 'EarlyStopping' callback
earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
# %%time

#  Trains the neural network
history = model.fit(
    x=x_tr,
    y=y_tr,
    epochs=100,
    batch_size=32,
    validation_data=(x_va, y_va),
    callbacks=[earlystopping_cb],
    class_weight=class_weights,
)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 15s 16ms/step - loss: 2.1349 - accuracy: 0.2557 - val_loss: 1.7933 - val_accuracy: 0.3393
# Epoch 2/100
# 184/184 [==============================] - 2s 11ms/step - loss: 1.6435 - accuracy: 0.3606 - val_loss: 1.4957 - val_accuracy: 0.5061
# Epoch 3/100
# 184/184 [==============================] - 2s 11ms/step - loss: 1.4557 - accuracy: 0.4437 - val_loss: 1.1474 - val_accuracy: 0.6361
# Epoch 4/100
# 184/184 [==============================] - 2s 11ms/step - loss: 1.2777 - accuracy: 0.5171 - val_loss: 0.9660 - val_accuracy: 0.7015
# Epoch 5/100
# 184/184 [==============================] - 2s 13ms/step - loss: 1.1534 - accuracy: 0.5774 - val_loss: 0.8331 - val_accuracy: 0.7091
# Epoch 6/100
# 184/184 [==============================] - 2s 13ms/step - loss: 1.0390 - accuracy: 0.6226 - val_loss: 0.7679 - val_accuracy: 0.7491
# Epoch 7/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.9836 - accuracy: 0.6410 - val_loss: 0.7561 - val_accuracy: 0.7194
# Epoch 8/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.8995 - accuracy: 0.6734 - val_loss: 0.7046 - val_accuracy: 0.7665
# Epoch 9/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.8450 - accuracy: 0.6935 - val_loss: 0.6739 - val_accuracy: 0.7618
# Epoch 10/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.8216 - accuracy: 0.7033 - val_loss: 0.6681 - val_accuracy: 0.7642
# Epoch 11/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.8085 - accuracy: 0.7152 - val_loss: 0.6361 - val_accuracy: 0.7749
# Epoch 12/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.7652 - accuracy: 0.7269 - val_loss: 0.6499 - val_accuracy: 0.7669
# Epoch 13/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.7518 - accuracy: 0.7310 - val_loss: 0.5629 - val_accuracy: 0.7844
# Epoch 14/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7125 - accuracy: 0.7417 - val_loss: 0.5702 - val_accuracy: 0.7852
# Epoch 15/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.7085 - accuracy: 0.7483 - val_loss: 0.5698 - val_accuracy: 0.7840
# Epoch 16/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6737 - accuracy: 0.7599 - val_loss: 0.5570 - val_accuracy: 0.7931
# Epoch 17/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6588 - accuracy: 0.7624 - val_loss: 0.5932 - val_accuracy: 0.7844
# Epoch 18/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6341 - accuracy: 0.7777 - val_loss: 0.5231 - val_accuracy: 0.8038
# Epoch 19/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.6130 - accuracy: 0.7784 - val_loss: 0.5079 - val_accuracy: 0.8062
# Epoch 20/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.6040 - accuracy: 0.7884 - val_loss: 0.5153 - val_accuracy: 0.8046
# Epoch 21/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5845 - accuracy: 0.7944 - val_loss: 0.5154 - val_accuracy: 0.8002
# Epoch 22/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.5675 - accuracy: 0.7990 - val_loss: 0.4899 - val_accuracy: 0.8212
# Epoch 23/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5514 - accuracy: 0.8032 - val_loss: 0.4905 - val_accuracy: 0.8121
# Epoch 24/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5542 - accuracy: 0.8065 - val_loss: 0.5117 - val_accuracy: 0.8090
# Epoch 25/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5372 - accuracy: 0.8049 - val_loss: 0.5180 - val_accuracy: 0.7931
# Epoch 26/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.5043 - accuracy: 0.8212 - val_loss: 0.4810 - val_accuracy: 0.8181
# Epoch 27/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5270 - accuracy: 0.8110 - val_loss: 0.4903 - val_accuracy: 0.8066
# Epoch 28/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5127 - accuracy: 0.8206 - val_loss: 0.4650 - val_accuracy: 0.8232
# Epoch 29/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.4841 - accuracy: 0.8228 - val_loss: 0.4954 - val_accuracy: 0.8082
# Epoch 30/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.4627 - accuracy: 0.8318 - val_loss: 0.4731 - val_accuracy: 0.8224
# Epoch 31/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.4637 - accuracy: 0.8336 - val_loss: 0.4874 - val_accuracy: 0.8098
# Epoch 32/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.4774 - accuracy: 0.8296 - val_loss: 0.5108 - val_accuracy: 0.8070
# Epoch 33/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.4524 - accuracy: 0.8370 - val_loss: 0.4527 - val_accuracy: 0.8312
# Epoch 34/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.4570 - accuracy: 0.8382 - val_loss: 0.4679 - val_accuracy: 0.8224
# Epoch 35/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.4316 - accuracy: 0.8437 - val_loss: 0.4610 - val_accuracy: 0.8252
# Epoch 36/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.4162 - accuracy: 0.8506 - val_loss: 0.4879 - val_accuracy: 0.8248
# Epoch 37/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.4264 - accuracy: 0.8534 - val_loss: 0.4649 - val_accuracy: 0.8220
# Epoch 38/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.4158 - accuracy: 0.8532 - val_loss: 0.4692 - val_accuracy: 0.8248
# Epoch 39/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.4144 - accuracy: 0.8571 - val_loss: 0.4524 - val_accuracy: 0.8256
# Epoch 40/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3991 - accuracy: 0.8634 - val_loss: 0.4492 - val_accuracy: 0.8252
# Epoch 41/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3862 - accuracy: 0.8634 - val_loss: 0.4217 - val_accuracy: 0.8347
# Epoch 42/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3571 - accuracy: 0.8720 - val_loss: 0.4315 - val_accuracy: 0.8327
# Epoch 43/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.3826 - accuracy: 0.8625 - val_loss: 0.4627 - val_accuracy: 0.8315
# Epoch 44/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.3810 - accuracy: 0.8664 - val_loss: 0.4620 - val_accuracy: 0.8343
# Epoch 45/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3455 - accuracy: 0.8703 - val_loss: 0.4546 - val_accuracy: 0.8442
# Epoch 46/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3398 - accuracy: 0.8802 - val_loss: 0.4333 - val_accuracy: 0.8383
# Epoch 47/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3818 - accuracy: 0.8636 - val_loss: 0.4850 - val_accuracy: 0.8280
# Epoch 48/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3489 - accuracy: 0.8778 - val_loss: 0.4474 - val_accuracy: 0.8315
# Epoch 49/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.3168 - accuracy: 0.8814 - val_loss: 0.4370 - val_accuracy: 0.8434
# Epoch 50/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.3345 - accuracy: 0.8788 - val_loss: 0.4564 - val_accuracy: 0.8304
# Epoch 51/100
# 184/184 [==============================] - 2s 14ms/step - loss: 0.3186 - accuracy: 0.8873 - val_loss: 0.4204 - val_accuracy: 0.8415
# Epoch 52/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3126 - accuracy: 0.8855 - val_loss: 0.4503 - val_accuracy: 0.8319
# Epoch 53/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3040 - accuracy: 0.8851 - val_loss: 0.4359 - val_accuracy: 0.8363
# Epoch 54/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2820 - accuracy: 0.8931 - val_loss: 0.4315 - val_accuracy: 0.8478
# Epoch 55/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.2993 - accuracy: 0.8919 - val_loss: 0.4161 - val_accuracy: 0.8482
# Epoch 56/100
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2971 - accuracy: 0.8952 - val_loss: 0.4514 - val_accuracy: 0.8403
# Epoch 57/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.3111 - accuracy: 0.8906 - val_loss: 0.4926 - val_accuracy: 0.8442
# Epoch 58/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2888 - accuracy: 0.8919 - val_loss: 0.4669 - val_accuracy: 0.8438
# Epoch 59/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2985 - accuracy: 0.8907 - val_loss: 0.4067 - val_accuracy: 0.8474
# Epoch 60/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2824 - accuracy: 0.8924 - val_loss: 0.4016 - val_accuracy: 0.8446
# Epoch 61/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.2624 - accuracy: 0.9047 - val_loss: 0.4719 - val_accuracy: 0.8272
# Epoch 62/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.2790 - accuracy: 0.8957 - val_loss: 0.4601 - val_accuracy: 0.8415
# Epoch 63/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.2869 - accuracy: 0.8945 - val_loss: 0.4286 - val_accuracy: 0.8442
# Epoch 64/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2688 - accuracy: 0.9006 - val_loss: 0.4217 - val_accuracy: 0.8533
# Epoch 65/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2676 - accuracy: 0.9023 - val_loss: 0.4099 - val_accuracy: 0.8498
# Epoch 66/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2437 - accuracy: 0.9113 - val_loss: 0.4083 - val_accuracy: 0.8522
# Epoch 67/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2387 - accuracy: 0.9128 - val_loss: 0.4019 - val_accuracy: 0.8530
# Epoch 68/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.2478 - accuracy: 0.9072 - val_loss: 0.4073 - val_accuracy: 0.8510
# Epoch 69/100
# 184/184 [==============================] - 3s 15ms/step - loss: 0.2252 - accuracy: 0.9176 - val_loss: 0.3888 - val_accuracy: 0.8652
# Epoch 70/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2222 - accuracy: 0.9137 - val_loss: 0.4238 - val_accuracy: 0.8502
# Epoch 71/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2557 - accuracy: 0.9076 - val_loss: 0.4326 - val_accuracy: 0.8462
# Epoch 72/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2422 - accuracy: 0.9106 - val_loss: 0.4420 - val_accuracy: 0.8454
# Epoch 73/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2203 - accuracy: 0.9149 - val_loss: 0.3919 - val_accuracy: 0.8541
# Epoch 74/100
# 184/184 [==============================] - 2s 14ms/step - loss: 0.2363 - accuracy: 0.9144 - val_loss: 0.4198 - val_accuracy: 0.8553
# Epoch 75/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.2331 - accuracy: 0.9154 - val_loss: 0.3935 - val_accuracy: 0.8593
# Epoch 76/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2439 - accuracy: 0.9159 - val_loss: 0.5034 - val_accuracy: 0.8359
# Epoch 77/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2030 - accuracy: 0.9198 - val_loss: 0.4492 - val_accuracy: 0.8415
# Epoch 78/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2363 - accuracy: 0.9152 - val_loss: 0.4344 - val_accuracy: 0.8510
# Epoch 79/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.2156 - accuracy: 0.9215 - val_loss: 0.4402 - val_accuracy: 0.8537
# CPU times: user 2min 38s, sys: 11.4 s, total: 2min 49s
# Wall time: 3min 8s

# %%
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv("/content/drive/MyDrive/LY Project/cnn_two_layers_history.csv")

model.save_weights("/content/drive/MyDrive/LY Project/cnn_two_layers_weights.h5")

# %%
# Plots neural network performance metrics for train and validation
fig, axs = plt.subplots(1, 2, figsize=(20, 5))
plt.suptitle('Convolutional Netural Network with MFCCs', size=15)
results = pd.DataFrame(history.history)
results[["loss", "val_loss"]].plot(ax=axs[0])
axs[0].set_title("Validation loss {:.3f} (mean last 3)".format(np.mean(history.history["val_loss"][-3:])))
results[["accuracy", "val_accuracy"]].plot(ax=axs[1])
axs[1].set_title("Validation accuracy {:.3f} (mean last 3)".format(np.mean(history.history["val_accuracy"][-3:])))
plt.savefig("/content/drive/MyDrive/LY Project/cnn_two_layers_training_curves.png")
plt.show()

# %%
# Collect loss and accuracy for the test set
loss_te, accuracy_te = model.evaluate(x_te, y_te)

print("Test loss: {:.2f}".format(loss_te))
print("Test accuracy: {:.2f}%".format(100 * accuracy_te))
# Out:
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3824 - accuracy: 0.8674
# Test loss: 0.38
# Test accuracy: 86.74%

# %%
# Compute test set predictions
predictions = model.predict(x_te)

pred = []

for i in predictions:
    pred.append(np.argmax(i))
    
from sklearn.metrics import ConfusionMatrixDisplay

labels = {'angry':0,'disgust':1,'fear':2,'happy':3,'neutral':4,'sad':5,'surprise':6}

def plot_confusion_matrices(y_true, y_pred):

    # Create two subplots
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

    # Plots the standard confusion matrix
    ax1.set_title("Confusion Matrix (counts)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, ax=ax1)

    # Plots the normalized confusion matrix
    ax2.set_title("Confusion Matrix (ratios)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, normalize="true", ax=ax2)
    plt.savefig("/content/drive/MyDrive/LY Project/cnn_two_layers_confusion_matrices.png")
    plt.show()

# Plot confusion matrices
plot_confusion_matrices(y_te, pred)
# Out:
# 30/30 [==============================] - 0s 4ms/step
